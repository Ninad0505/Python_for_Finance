# %%
import pandas as pd
import pandas_datareader as pdr
import datetime as dt
import numpy as np

# %%
def test_correlation(ticker):
    df = pdr.get_data_yahoo(ticker, start)
    lr = log_returns.copy()
    lr[ticker] = np.log(df['Adj Close']/df['Adj Close'].shift())
    return lr.corr()

# %%
tickers = ['SBIN.NS', 'HDFCBANK.NS', 'RELIANCE.NS', 'ITC.NS', 'TCS.NS', 'INFY.NS', 'ICICIBANK.NS']

start = dt.datetime(2020, 1, 1)

data = pdr.get_data_yahoo(tickers, start)

data = data['Adj Close']
data
# Out:
# Symbols        SBIN.NS  HDFCBANK.NS  RELIANCE.NS      ITC.NS       TCS.NS  \
# Date
# 2020-01-01  326.298187  1258.457886  1480.595825  205.544617  2075.234863
# 2020-01-02  331.029938  1266.479614  1505.802124  207.055344  2065.709229
# 2020-01-03  325.566467  1248.418579  1507.616455  205.889923  2106.876953
# 2020-01-06  311.224731  1221.401001  1472.651367  202.954803  2106.685059
# 2020-01-07  310.639374  1240.741455  1495.307617  203.170624  2111.854736
# ...                ...          ...          ...         ...          ...
# 2022-11-17  599.049988  1618.150024  2599.050049  343.700012  3349.000000
# 2022-11-18  602.700012  1613.900024  2597.649902  341.049988  3343.449951
# 2022-11-21  598.099976  1597.349976  2550.899902  337.200012  3283.500000
# 2022-11-22  599.099976  1595.000000  2565.050049  340.250000  3314.949951
# 2022-11-23  607.650024  1599.150024  2557.050049  339.799988  3308.300049
#
# Symbols         INFY.NS  ICICIBANK.NS
# Date
# ...

# %%
log_returns = np.log(data/data.shift())
log_returns
# Out:
# Symbols      SBIN.NS  HDFCBANK.NS  RELIANCE.NS    ITC.NS    TCS.NS   INFY.NS  \
# Date
# 2020-01-01       NaN          NaN          NaN       NaN       NaN       NaN
# 2020-01-02  0.014397     0.006354     0.016881  0.007323 -0.004601 -0.002922
# 2020-01-03 -0.016642    -0.014363     0.001204 -0.005644  0.019733  0.015263
# 2020-01-06 -0.045051    -0.021879    -0.023465 -0.014358 -0.000091 -0.009631
# 2020-01-07 -0.001883     0.015711     0.015268  0.001063  0.002451 -0.014931
# ...              ...          ...          ...       ...       ...       ...
# 2022-11-17 -0.001168    -0.009074     0.002581 -0.001163 -0.001894 -0.009655
# 2022-11-18  0.006075    -0.002630    -0.000539 -0.007740 -0.001659  0.003773
# 2022-11-21 -0.007662    -0.010308    -0.018161 -0.011353 -0.018093 -0.015942
# 2022-11-22  0.001671    -0.001472     0.005532  0.009004  0.009533  0.010688
# 2022-11-23  0.014171     0.002599    -0.003124 -0.001323 -0.002008 -0.001199
#
# Symbols     ICICIBANK.NS
# Date
# ...

# %%
start = dt.datetime(2020, 1, 1)
Nifty50 = pdr.get_data_yahoo("^NSEI", start)
log_returns['Nifty50'] = np.log(Nifty50['Adj Close']/Nifty50['Adj Close'].shift())
log_returns.corr()
# Out:
# Symbols        SBIN.NS  HDFCBANK.NS  RELIANCE.NS    ITC.NS    TCS.NS  \
# Symbols
# SBIN.NS       1.000000     0.578329     0.437779  0.477894  0.332411
# HDFCBANK.NS   0.578329     1.000000     0.472898  0.346081  0.375729
# RELIANCE.NS   0.437779     0.472898     1.000000  0.317266  0.432791
# ITC.NS        0.477894     0.346081     0.317266  1.000000  0.278704
# TCS.NS        0.332411     0.375729     0.432791  0.278704  1.000000
# INFY.NS       0.348372     0.426894     0.402666  0.284722  0.718875
# ICICIBANK.NS  0.724188     0.693112     0.452299  0.366420  0.382926
# Nifty50       0.736712     0.794388     0.713111  0.531387  0.626953
#
# Symbols        INFY.NS  ICICIBANK.NS   Nifty50
# Symbols
# SBIN.NS       0.348372      0.724188  0.736712
# HDFCBANK.NS   0.426894      0.693112  0.794388
# RELIANCE.NS   0.402666      0.452299  0.713111
# ITC.NS        0.284722      0.366420  0.531387
# TCS.NS        0.718875      0.382926  0.626953
# ...

# %%
test_correlation("LQD")
# Out:
# Symbols        SBIN.NS  HDFCBANK.NS  RELIANCE.NS    ITC.NS    TCS.NS  \
# Symbols
# SBIN.NS       1.000000     0.578329     0.437779  0.477894  0.332411
# HDFCBANK.NS   0.578329     1.000000     0.472898  0.346081  0.375729
# RELIANCE.NS   0.437779     0.472898     1.000000  0.317266  0.432791
# ITC.NS        0.477894     0.346081     0.317266  1.000000  0.278704
# TCS.NS        0.332411     0.375729     0.432791  0.278704  1.000000
# INFY.NS       0.348372     0.426894     0.402666  0.284722  0.718875
# ICICIBANK.NS  0.724188     0.693112     0.452299  0.366420  0.382926
# Nifty50       0.736712     0.794388     0.713111  0.531387  0.626953
# LQD           0.137308     0.113228     0.100620 -0.000197  0.109156
#
# Symbols        INFY.NS  ICICIBANK.NS   Nifty50       LQD
# Symbols
# SBIN.NS       0.348372      0.724188  0.736712  0.137308
# HDFCBANK.NS   0.426894      0.693112  0.794388  0.113228
# RELIANCE.NS   0.402666      0.452299  0.713111  0.100620
# ...

# %%
test_correlation("TLT")
# Out:
# Symbols        SBIN.NS  HDFCBANK.NS  RELIANCE.NS    ITC.NS    TCS.NS  \
# Symbols
# SBIN.NS       1.000000     0.578329     0.437779  0.477894  0.332411
# HDFCBANK.NS   0.578329     1.000000     0.472898  0.346081  0.375729
# RELIANCE.NS   0.437779     0.472898     1.000000  0.317266  0.432791
# ITC.NS        0.477894     0.346081     0.317266  1.000000  0.278704
# TCS.NS        0.332411     0.375729     0.432791  0.278704  1.000000
# INFY.NS       0.348372     0.426894     0.402666  0.284722  0.718875
# ICICIBANK.NS  0.724188     0.693112     0.452299  0.366420  0.382926
# Nifty50       0.736712     0.794388     0.713111  0.531387  0.626953
# TLT          -0.122527    -0.077774    -0.144798 -0.044678 -0.075886
#
# Symbols        INFY.NS  ICICIBANK.NS   Nifty50       TLT
# Symbols
# SBIN.NS       0.348372      0.724188  0.736712 -0.122527
# HDFCBANK.NS   0.426894      0.693112  0.794388 -0.077774
# RELIANCE.NS   0.402666      0.452299  0.713111 -0.144798
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

def visualize_correlation(ticker1, ticker2):
    df = pdr.get_data_yahoo([ticker1, ticker2], start)
    df = df['Adj Close']
    df = df/df.iloc[2]               #nifty had zero value at 1st row and tlt had zero value on 2nd row
    fig, ax = plt.subplots()
    df.plot(ax=ax)
    
visualize_correlation("^NSEI", "TLT")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pdr.get_data_yahoo(["^NSEI", "TLT"], start)
df = df['Adj Close']
df
# Out:
# Symbols            ^NSEI         TLT
# Date
# 2019-12-31           NaN  129.063126
# 2020-01-01  12182.500000         NaN
# 2020-01-02  12282.200195  130.520660
# 2020-01-03  12226.650391  132.530685
# 2020-01-06  11993.049805  131.778137
# ...                  ...         ...
# 2022-11-17  18343.900391  100.330002
# 2022-11-18  18307.650391   99.639999
# 2022-11-21  18159.949219  100.059998
# 2022-11-22  18244.199219  101.480003
# 2022-11-23  18267.250000         NaN
#
# [752 rows x 2 columns]

# %%
visualize_correlation("HDFCBANK.NS", "TLT")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cov = log_returns.cov()

# %%
cov
# Out:
# Symbols        SBIN.NS  HDFCBANK.NS  RELIANCE.NS    ITC.NS    TCS.NS  \
# Symbols
# SBIN.NS       0.000567     0.000276     0.000229  0.000218  0.000137
# HDFCBANK.NS   0.000276     0.000401     0.000208  0.000133  0.000130
# RELIANCE.NS   0.000229     0.000208     0.000484  0.000134  0.000165
# ITC.NS        0.000218     0.000133     0.000134  0.000368  0.000093
# TCS.NS        0.000137     0.000130     0.000165  0.000093  0.000300
# INFY.NS       0.000161     0.000166     0.000172  0.000106  0.000242
# ICICIBANK.NS  0.000423     0.000340     0.000244  0.000172  0.000163
# Nifty50       0.000256     0.000232     0.000229  0.000149  0.000158
#
# Symbols        INFY.NS  ICICIBANK.NS   Nifty50
# Symbols
# SBIN.NS       0.000161      0.000423  0.000256
# HDFCBANK.NS   0.000166      0.000340  0.000232
# RELIANCE.NS   0.000172      0.000244  0.000229
# ITC.NS        0.000106      0.000172  0.000149
# TCS.NS        0.000242      0.000163  0.000158
# ...

# %%
var = log_returns['Nifty50'].var()

# %%
var
# Out:
# 0.00021241381834596415

# %%
cov.loc['SBIN.NS', 'Nifty50']/var
# Out:
# 1.204050860156274
